# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Generate random data
num_samples = 100000
a = np.random.rand(num_samples)
b = np.random.rand(num_samples)

# Create labels by performing the specified operations
labels = (a + b)

# Create a Sequential model
model = Sequential()

# Add layers to the model
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(x=np.column_stack((a, b)), y=labels, epochs=50, batch_size=32, validation_split=0.2)

# Test the model with new data
test_a = np.random.rand(10)
test_b = np.random.rand(10)

predictions = model.predict(np.column_stack((test_a, test_b)))
print("Predictions:", predictions.flatten())
print((test_a[0] + test_b[0]))
# Out:
# WARNING:tensorflow:From c:\Users\mmvergara\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\mmvergara\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\mmvergara\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\mmvergara\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# ...

# %%
# Test the model with new data

for i in range(4):
  test_a = [float(np.random.randint(1,1000))]
  test_b = [float(np.random.randint(1,1000))]
  predictions = model.predict(np.column_stack((test_a, test_b)))
  print("Input:", test_a,test_b)
  print("Predictions:", predictions.flatten())
  print("correct ans:", (test_a[0] + test_b[0]))
# Out:
# 1/1 [==============================] - 0s 45ms/step
# Input: [752.0] [275.0]
# Predictions: [1026.999]
# correct ans: 1027.0
# 1/1 [==============================] - 0s 48ms/step
# Input: [335.0] [27.0]
# Predictions: [361.9929]
# correct ans: 362.0
# 1/1 [==============================] - 0s 34ms/step
# Input: [43.0] [519.0]
# Predictions: [562.0355]
# correct ans: 562.0
# 1/1 [==============================] - 0s 31ms/step
# Input: [658.0] [158.0]
# Predictions: [815.9934]
# correct ans: 816.0
